# %%
import pandas as pd

leitos1 = pd.read_csv("Leitos_2023.csv", encoding="latin-1")
display(leitos1)
# Out:
#          COMP    REGIAO  UF                MUNICIPIO  MOTIVO_DESABILITACAO  \
# 0      202301  NORDESTE  PE  CABO DE SANTO AGOSTINHO                   NaN
# 1      202301  NORDESTE  PE  CABO DE SANTO AGOSTINHO                   NaN
# 2      202301  NORDESTE  PE  CABO DE SANTO AGOSTINHO                   NaN
# 3      202301  NORDESTE  PE  CABO DE SANTO AGOSTINHO                   NaN
# 4      202301  NORDESTE  PE  CABO DE SANTO AGOSTINHO                   NaN
# ...       ...       ...  ..                      ...                   ...
# 84466  202312  NORDESTE  PE                 IGARASSU                   NaN
# 84467  202312   SUDESTE  SP      SAO JOSE DOS CAMPOS                   NaN
# 84468  202312   SUDESTE  SP                  ITAPEVI                   NaN
# 84469  202312  NORDESTE  PB                    CONDE                   NaN
# 84470  202312  NORDESTE  MA                BACABEIRA                   NaN
#
#           CNES                               NOME_ESTABELECIMENTO  \
# ...

# %%
import pandas as pd

leitos2 = pd.read_csv("Leitos_2024.csv", encoding="latin-1")
display(leitos2)
# Out:
#          COMP    REGIAO  UF                MUNICIPIO  MOTIVO_DESABILITACAO  \
# 0      202401  NORDESTE  PE  CABO DE SANTO AGOSTINHO                   NaN
# 1      202401  NORDESTE  PE  CABO DE SANTO AGOSTINHO                   NaN
# 2      202401  NORDESTE  PE  CABO DE SANTO AGOSTINHO                   NaN
# 3      202401  NORDESTE  PE  CABO DE SANTO AGOSTINHO                   NaN
# 4      202401  NORDESTE  PE  CABO DE SANTO AGOSTINHO                   NaN
# ...       ...       ...  ..                      ...                   ...
# 85220  202412   SUDESTE  SP                SAO ROQUE                   NaN
# 85221  202412  NORDESTE  PE                 IGARASSU                   NaN
# 85222  202412   SUDESTE  SP                  ITAPEVI                   NaN
# 85223  202412  NORDESTE  PB                    CONDE                   NaN
# 85224  202412  NORDESTE  MA                BACABEIRA                   NaN
#
#           CNES                    NOME_ESTABELECIMENTO  \
# ...

# %%
import pandas as pd
import numpy as np

leitos3 = pd.read_csv("Leitos_2025.csv", sep=";", encoding="latin-1")
display(leitos3)
# Out:
#          COMP    REGIAO  UF  CO_IBGE                MUNICIPIO  \
# 0      202501  NORDESTE  PE   260290  CABO DE SANTO AGOSTINHO
# 1      202501  NORDESTE  PE   260290  CABO DE SANTO AGOSTINHO
# 2      202501  NORDESTE  PE   260290  CABO DE SANTO AGOSTINHO
# 3      202501  NORDESTE  PE   260290  CABO DE SANTO AGOSTINHO
# 4      202501  NORDESTE  PE   260290  CABO DE SANTO AGOSTINHO
# ...       ...       ...  ..      ...                      ...
# 50169  202507   SUDESTE  SP   355060                SAO ROQUE
# 50170  202507  NORDESTE  PE   260680                 IGARASSU
# 50171  202507   SUDESTE  SP   352250                  ITAPEVI
# 50172  202507  NORDESTE  PB   250460                    CONDE
# 50173  202507  NORDESTE  MA   210125                BACABEIRA
#
#        MOTIVO_DESABILITACAO     CNES                    NOME_ESTABELECIMENTO  \
# 0                       NaN       27              CASA DE SAUDE SANTA HELENA
# ...
